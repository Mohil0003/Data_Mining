# %% [markdown]
# <center>
# <h1>Project Task - 2</h1>
# <h3>Name: Mohil Parmar</h3>
# <h3>Enrollment no: 23010101192</h3>
# </center>

# %% [markdown]
# ### 1. Import the pandas Libraries

# %%
import pandas as pd

# %% [markdown]
# ### 2. Read csv

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# ### 3. Print Data from csv

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### 4. First 10 Rows

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %% [markdown]
# ### 5.  Last 10 Rows

# %%
df.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# ...

# %% [markdown]
# ### 6. Data type of each columns

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### 7. number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# ### 8. Display Summary Information

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### 9. dataset index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %% [markdown]
# ### 10. count null value

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### 11. Access rows by their integer location

# %%
df.iloc[1:4]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
#
#    ca  thal  target
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0

# %% [markdown]
# ### 12. Delete a specific Column

# %%
df.drop('ca', axis=1, inplace=True)

# %% [markdown]
# ### 13. Create a new Column

# %%
df['Status'] = 'Active'

# %% [markdown]
# ### 14. Perform Condition Selection on DataFrame

# %%
df[df['thal'] > 2]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 7      55    1   0       160   289    0        0      145      1      0.8
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  thal  target  Status
# 0         2     3       0  Active
# ...

# %% [markdown]
# ### 15. groupby in sex and target

# %%
df.groupby(['sex', 'target']).size()
# Out:
# sex  target
# 0    0          86
#      1         226
# 1    0         413
#      1         300
# dtype: int64

# %% [markdown]
# ### 16.  Compute the mean of value

# %%
df['trestbps'].mean()
# Out:
# 131.61170731707318

# %% [markdown]
# ### 17. Count non-null value (column)

# %%
df.count()
# Out:
# age         1025
# sex         1025
# cp          1025
# trestbps    1025
# chol        1025
# fbs         1025
# restecg     1025
# thalach     1025
# exang       1025
# oldpeak     1025
# slope       1025
# thal        1025
# target      1025
# Status      1025
# dtype: int64

# %% [markdown]
# ### 18. Find Minimun or Maximum values of age

# %%
df['age'].min()
# Out:
# 29

# %%
df['age'].max()
# Out:
# 77

# %% [markdown]
# ### 19.count unique age

# %%
df['age'].nunique()
# Out:
# 41

# %% [markdown]
# ### 20. count the value of Status

# %%
df['Status'].value_counts()
# Out:
# Status
# Active    1025
# Name: count, dtype: int64

# %% [markdown]
# ### 21.describe fun all value if not numeric

# %%
df.describe(include='all')
# Out:
#                 age          sex           cp     trestbps        chol  \
# count   1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# unique          NaN          NaN          NaN          NaN         NaN
# top             NaN          NaN          NaN          NaN         NaN
# freq            NaN          NaN          NaN          NaN         NaN
# mean      54.434146     0.695610     0.942439   131.611707   246.00000
# std        9.072290     0.460373     1.029641    17.516718    51.59251
# min       29.000000     0.000000     0.000000    94.000000   126.00000
# 25%       48.000000     0.000000     0.000000   120.000000   211.00000
# 50%       56.000000     1.000000     1.000000   130.000000   240.00000
# 75%       61.000000     1.000000     2.000000   140.000000   275.00000
# max       77.000000     1.000000     3.000000   200.000000   564.00000
#
#                 fbs      restecg      thalach        exang      oldpeak  \
# ...

# %% [markdown]
# ### 22. covariance  between pairs of attributes.

# %%
df[['age', 'cp']].cov()
# Out:
#            age        cp
# age  82.306450 -0.672251
# cp   -0.672251  1.060160

# %% [markdown]
# ### 23. Unique display

# %%
df['age'].unique()
# Out:
# array([52, 53, 70, 61, 62, 58, 55, 46, 54, 71, 43, 34, 51, 50, 60, 67, 45,
#        63, 42, 44, 56, 57, 59, 64, 65, 41, 66, 38, 49, 48, 29, 37, 47, 68,
#        76, 40, 39, 77, 69, 35, 74], dtype=int64)

# %% [markdown]
# ### 24. corr of numeric values

# %%
df.corr(numeric_only=True)
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
# ...

# %% [markdown]
# ### 25. Display Scatter plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("heart.csv")

plt.scatter(df['age'], df['trestbps'])
plt.title('Scatter Plot: age vs trestbps')
plt.xlabel('age')
plt.ylabel('trestbps')
plt.grid(True)
plt.show()
